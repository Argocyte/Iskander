# %%
from pypdf import PdfReader
reader = PdfReader(r'C:\Users\argoc\Downloads\ICA Guidance Notes EN.pdf')
print(f'Total pages: {len(reader.pages)}')
# Check key pages to verify offsets
for i in [58, 59, 60, 70, 71, 84, 85, 98, 99, 112, 113]:
    text = reader.pages[i].extract_text()[:300]
    print(f'=== PDF Page {i} ===')
    print(text)
    print()
